# %%
import os
import pandas as pd
import numpy as np

#建立Model Information的Schema
if not os.path.isdir("../model"):
    os.makedirs("../model")
    
SchemaColumn = ['Name','Description','Sample']

SchemaName = ['FileName','ColumnList','WindowSize','NumOfPredictDay','Layer',
              'Loss','Optimizer','BatchSize','Epoch','ValidationSplit','ModelName']

SchemaDescription = ['檔案名稱','選擇的Column','以過去幾天的資料去做訓練、預測','要預測的天數','神經網路的層數',
                     'Loss Function的選擇','優化器的選擇','驗證集比例','訓練時Batch的大小',
                     '訓練幾次','儲存Model的名稱']

SchemaSample = ['2002.csv,3008.csv','["成交股數","成交金額","成交筆數","開盤價","最後揭示買價","最後揭示賣價","收盤價"]',
                '50','1,7,10,30','[len(ColumnList), 50, 100,NumOfPredictDay]','mse','adam','0.1','512',
                '10','0.h5,1.h5,2.h5']

ModelInformationSchema = pd.DataFrame(columns=SchemaColumn,index=range(len(SchemaName)))
for i in range(len(SchemaName)):
    ModelInformationSchema.iloc[i,0] = SchemaName[i]
    ModelInformationSchema.iloc[i,1] = SchemaDescription[i]
    ModelInformationSchema.iloc[i,2] = SchemaSample[i]
    #print(SchemaName[i],SchemaDescription[i],SchemaSample2[i])
    
ModelInformationSchema.to_csv('../model/ModelInformationSchema.csv')
ModelInformationSchema
#len(SchemaName)
# Out:
#                Name       Description  \
# 0          FileName              檔案名稱
# 1        ColumnList         選擇的Column
# 2        WindowSize   以過去幾天的資料去做訓練、預測
# 3   NumOfPredictDay            要預測的天數
# 4             Layer           神經網路的層數
# 5              Loss  Loss Function的選擇
# 6         Optimizer            優化器的選擇
# 7         BatchSize             驗證集比例
# 8             Epoch       訓練時Batch的大小
# 9   ValidationSplit              訓練幾次
# 10        ModelName        儲存Model的名稱
#
#                                                Sample
# 0                                   2002.csv,3008.csv
# 1   ["成交股數","成交金額","成交筆數","開盤價","最後揭示買價","最後揭示賣價",...
# 2                                                  50
# 3                                           1,7,10,30
# 4          [len(ColumnList), 50, 100,NumOfPredictDay]
# 5                                                 mse
# 6                                                adam
# 7                                                 0.1
# 8                                                 512
# 9                                                  10
# 10                                     0.h5,1.h5,2.h5

# %%
Filename = "2002.csv"
ColumnList = ["成交股數","成交金額","成交筆數","開盤價","最後揭示買價","最後揭示賣價","收盤價"]
WindowSize = 50
NumOfPredictDay = 30

Layer = [len(ColumnList), 50, 100,NumOfPredictDay]
Loss = "mse"
Optimizer = "adam"

BatchSize = 512
Epoch = 5
ValidationSplit = 0.1

import os
DirList = list(os.listdir("../data"))[1:]

FilenameList = DirList
#ColumnList = []
WindowSizeList = [50,100,150]
NumOfPredictDayList = [3,7,10,30]
#Layer = []
#Loss = []
#Optimizer = []
#BatchSize = []
EpochList = [1,5,10,50]
#ValidationSplit = []
                
#建立Model Information

ModelInformationColumn = SchemaName

NumofIndex = len(FilenameList)*len(WindowSizeList)*len(NumOfPredictDayList)*len(EpochList)
ModelInformation = pd.DataFrame(columns=ModelInformationColumn,index=range(NumofIndex)) 

count = 0
for Filename in FilenameList:
    for WindowSize in WindowSizeList:
        for NumOfPredictDay in NumOfPredictDayList:
            for Epoch in EpochList:
                Layer = [len(ColumnList), 50, 100,NumOfPredictDay]
                ModelInformation.iloc[count,0] = Filename
                ModelInformation.iloc[count,1] = ColumnList
                ModelInformation.iloc[count,2] = WindowSize
                ModelInformation.iloc[count,3] = NumOfPredictDay
                ModelInformation.iloc[count,4] = Layer
                ModelInformation.iloc[count,5] = Loss
                ModelInformation.iloc[count,6] = Optimizer
                ModelInformation.iloc[count,7] = BatchSize
                ModelInformation.iloc[count,8] = Epoch
                ModelInformation.iloc[count,9] = ValidationSplit
                ModelInformation.iloc[count,10] = str(count) + ".h5"
                #print(count,end=' ')
                count += 1

ModelInformation.to_csv('../model/ModelInformation.csv')
ModelInformation.to_pickle('../model/ModelInformation.pickle')
ModelInformation
# Out:
#      FileName                                    ColumnList WindowSize  \
# 0    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 1    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 2    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 3    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 4    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 5    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 6    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 7    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 8    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 9    1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 10   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 11   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 12   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 13   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 14   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 15   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 16   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 17   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 18   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 19   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 20   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 21   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 22   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 23   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 24   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 25   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 26   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 27   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 28   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 29   1560.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# ..        ...                                           ...        ...
# 354  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 355  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 356  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 357  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 358  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 359  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 360  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 361  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 362  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 363  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 364  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 365  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 366  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 367  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 368  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 369  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 370  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 371  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 372  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 373  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 374  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 375  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 376  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 377  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 378  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 379  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 380  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 381  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 382  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 383  3481.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
#
#     NumOfPredictDay             Layer Loss Optimizer BatchSize Epoch  \
# 0                 3   [7, 50, 100, 3]  mse      adam       512     1
# 1                 3   [7, 50, 100, 3]  mse      adam       512     5
# 2                 3   [7, 50, 100, 3]  mse      adam       512    10
# 3                 3   [7, 50, 100, 3]  mse      adam       512    50
# 4                 7   [7, 50, 100, 7]  mse      adam       512     1
# 5                 7   [7, 50, 100, 7]  mse      adam       512     5
# 6                 7   [7, 50, 100, 7]  mse      adam       512    10
# 7                 7   [7, 50, 100, 7]  mse      adam       512    50
# 8                10  [7, 50, 100, 10]  mse      adam       512     1
# 9                10  [7, 50, 100, 10]  mse      adam       512     5
# 10               10  [7, 50, 100, 10]  mse      adam       512    10
# 11               10  [7, 50, 100, 10]  mse      adam       512    50
# 12               30  [7, 50, 100, 30]  mse      adam       512     1
# 13               30  [7, 50, 100, 30]  mse      adam       512     5
# 14               30  [7, 50, 100, 30]  mse      adam       512    10
# 15               30  [7, 50, 100, 30]  mse      adam       512    50
# 16                3   [7, 50, 100, 3]  mse      adam       512     1
# 17                3   [7, 50, 100, 3]  mse      adam       512     5
# 18                3   [7, 50, 100, 3]  mse      adam       512    10
# 19                3   [7, 50, 100, 3]  mse      adam       512    50
# 20                7   [7, 50, 100, 7]  mse      adam       512     1
# 21                7   [7, 50, 100, 7]  mse      adam       512     5
# 22                7   [7, 50, 100, 7]  mse      adam       512    10
# 23                7   [7, 50, 100, 7]  mse      adam       512    50
# 24               10  [7, 50, 100, 10]  mse      adam       512     1
# 25               10  [7, 50, 100, 10]  mse      adam       512     5
# 26               10  [7, 50, 100, 10]  mse      adam       512    10
# 27               10  [7, 50, 100, 10]  mse      adam       512    50
# 28               30  [7, 50, 100, 30]  mse      adam       512     1
# 29               30  [7, 50, 100, 30]  mse      adam       512     5
# ..              ...               ...  ...       ...       ...   ...
# 354               3   [7, 50, 100, 3]  mse      adam       512    10
# 355               3   [7, 50, 100, 3]  mse      adam       512    50
# 356               7   [7, 50, 100, 7]  mse      adam       512     1
# 357               7   [7, 50, 100, 7]  mse      adam       512     5
# 358               7   [7, 50, 100, 7]  mse      adam       512    10
# 359               7   [7, 50, 100, 7]  mse      adam       512    50
# 360              10  [7, 50, 100, 10]  mse      adam       512     1
# 361              10  [7, 50, 100, 10]  mse      adam       512     5
# 362              10  [7, 50, 100, 10]  mse      adam       512    10
# 363              10  [7, 50, 100, 10]  mse      adam       512    50
# 364              30  [7, 50, 100, 30]  mse      adam       512     1
# 365              30  [7, 50, 100, 30]  mse      adam       512     5
# 366              30  [7, 50, 100, 30]  mse      adam       512    10
# 367              30  [7, 50, 100, 30]  mse      adam       512    50
# 368               3   [7, 50, 100, 3]  mse      adam       512     1
# 369               3   [7, 50, 100, 3]  mse      adam       512     5
# 370               3   [7, 50, 100, 3]  mse      adam       512    10
# 371               3   [7, 50, 100, 3]  mse      adam       512    50
# 372               7   [7, 50, 100, 7]  mse      adam       512     1
# 373               7   [7, 50, 100, 7]  mse      adam       512     5
# 374               7   [7, 50, 100, 7]  mse      adam       512    10
# 375               7   [7, 50, 100, 7]  mse      adam       512    50
# 376              10  [7, 50, 100, 10]  mse      adam       512     1
# 377              10  [7, 50, 100, 10]  mse      adam       512     5
# 378              10  [7, 50, 100, 10]  mse      adam       512    10
# 379              10  [7, 50, 100, 10]  mse      adam       512    50
# 380              30  [7, 50, 100, 30]  mse      adam       512     1
# 381              30  [7, 50, 100, 30]  mse      adam       512     5
# 382              30  [7, 50, 100, 30]  mse      adam       512    10
# 383              30  [7, 50, 100, 30]  mse      adam       512    50
#
#     ValidationSplit ModelName
# 0               0.1      0.h5
# 1               0.1      1.h5
# 2               0.1      2.h5
# 3               0.1      3.h5
# 4               0.1      4.h5
# 5               0.1      5.h5
# 6               0.1      6.h5
# 7               0.1      7.h5
# 8               0.1      8.h5
# 9               0.1      9.h5
# 10              0.1     10.h5
# 11              0.1     11.h5
# 12              0.1     12.h5
# 13              0.1     13.h5
# 14              0.1     14.h5
# 15              0.1     15.h5
# 16              0.1     16.h5
# 17              0.1     17.h5
# 18              0.1     18.h5
# 19              0.1     19.h5
# 20              0.1     20.h5
# 21              0.1     21.h5
# 22              0.1     22.h5
# 23              0.1     23.h5
# 24              0.1     24.h5
# 25              0.1     25.h5
# 26              0.1     26.h5
# 27              0.1     27.h5
# 28              0.1     28.h5
# 29              0.1     29.h5
# ..              ...       ...
# 354             0.1    354.h5
# 355             0.1    355.h5
# 356             0.1    356.h5
# 357             0.1    357.h5
# 358             0.1    358.h5
# 359             0.1    359.h5
# 360             0.1    360.h5
# 361             0.1    361.h5
# 362             0.1    362.h5
# 363             0.1    363.h5
# 364             0.1    364.h5
# 365             0.1    365.h5
# 366             0.1    366.h5
# 367             0.1    367.h5
# 368             0.1    368.h5
# 369             0.1    369.h5
# 370             0.1    370.h5
# 371             0.1    371.h5
# 372             0.1    372.h5
# 373             0.1    373.h5
# 374             0.1    374.h5
# 375             0.1    375.h5
# 376             0.1    376.h5
# 377             0.1    377.h5
# 378             0.1    378.h5
# 379             0.1    379.h5
# 380             0.1    380.h5
# 381             0.1    381.h5
# 382             0.1    382.h5
# 383             0.1    383.h5
#
# [384 rows x 11 columns]

# %%
ModelInformation = pd.read_pickle('../model/ModelInformation.pickle')
