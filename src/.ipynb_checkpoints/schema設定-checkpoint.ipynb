# %%
import os
import pandas as pd
import numpy as np
    
#針對各個變數去做訓練和預測
Filename = "2002.csv"
ColumnList = ["成交股數","成交金額","成交筆數","開盤價","最後揭示買價","最後揭示賣價","收盤價"]
WindowSize = 50
NumOfPredictDay = 1

Layer = [len(ColumnList), 50, 100,NumOfPredictDay]
Loss = "mse"
Optimizer = "adam"

BatchSize = 512
Epoch = 10
ValidationSplit = 0.1

# %%
#建立Model Information的Schema
if not os.path.isdir("../model"):
    os.makedirs("../model")
    
SchemaColumn = ['Name','Description','Sample']

SchemaName = ['FileName','ColumnList','WindowSize','NumOfPredictDay','Layer',
              'Loss','Optimizer','ValidationSplit','BatchSize','Epoch','ModelName']

SchemaDescription = ['檔案名稱','選擇的Column','以過去幾天的資料去做訓練、預測','要預測的天數','神經網路的層數',
                     'Loss Function的選擇','優化器的選擇','驗證集大小','訓練時Batch的大小',
                     '訓練幾次','儲存Model的名稱']

SchemaSample = ['2002.csv,3008.csv','["成交股數","成交金額","成交筆數","開盤價","最後揭示買價","最後揭示賣價","收盤價"]',
                '50','1,7,10,30','[len(ColumnList), 50, 100,NumOfPredictDay]','mse','adam','0.1','512',
                '10','0.h5,1.h5,2.h5']

ModelInformationSchema = pd.DataFrame(columns=SchemaColumn,index=range(len(SchemaName)))
for i in range(len(SchemaName)):
    ModelInformationSchema.iloc[i,0] = SchemaName[i]
    ModelInformationSchema.iloc[i,1] = SchemaDescription[i]
    ModelInformationSchema.iloc[i,2] = SchemaSample[i]
    #print(SchemaName[i],SchemaDescription[i],SchemaSample2[i])
    
ModelInformationSchema.to_csv('../model/ModelInformationSchema.csv')
ModelInformationSchema
#len(SchemaName)
# Out:
#                Name       Description  \
# 0          FileName              檔案名稱
# 1        ColumnList         選擇的Column
# 2        WindowSize   以過去幾天的資料去做訓練、預測
# 3   NumOfPredictDay            要預測的天數
# 4             Layer           神經網路的層數
# 5              Loss  Loss Function的選擇
# 6         Optimizer            優化器的選擇
# 7   ValidationSplit             驗證集大小
# 8         BatchSize       訓練時Batch的大小
# 9             Epoch              訓練幾次
# 10        ModelName        儲存Model的名稱
#
#                                                Sample
# 0                                   2002.csv,3008.csv
# 1   ["成交股數","成交金額","成交筆數","開盤價","最後揭示買價","最後揭示賣價",...
# 2                                                  50
# 3                                           1,7,10,30
# 4          [len(ColumnList), 50, 100,NumOfPredictDay]
# 5                                                 mse
# 6                                                adam
# 7                                                 0.1
# 8                                                 512
# 9                                                  10
# 10                                     0.h5,1.h5,2.h5

# %%
Filename = "2002.csv"
ColumnList = ["成交股數","成交金額","成交筆數","開盤價","最後揭示買價","最後揭示賣價","收盤價"]
WindowSize = 50
NumOfPredictDay = 30

Layer = [len(ColumnList), 50, 100,NumOfPredictDay]
Loss = "mse"
Optimizer = "adam"

BatchSize = 512
Epoch = 5
ValidationSplit = 0.1

import os
DirList = list(os.listdir("../data"))[1:]

FilenameList = DirList
#ColumnList = []
WindowSizeList = [50,100,150]
NumOfPredictDayList = [3,7,10,30]
#Layer = []
#Loss = []
#Optimizer = []
#BatchSize = []
EpochList = [1,5,10,50]
#ValidationSplit = []
                

#建立Model Information

ModelInformationColumn = SchemaName

NumofIndex = len(FilenameList)*len(WindowSizeList)*len(NumOfPredictDayList)*len(EpochList)
print(len(FilenameList))
print(len(WindowSizeList))
print(len(NumOfPredictDayList))
print(len(EpochList))
print(NumofIndex)
ModelInformation = pd.DataFrame(columns=ModelInformationColumn,index=range(NumofIndex)) 

count = 0
for Filename in FilenameList:
    for WindowSize in WindowSizeList:
        for NumOfPredictDay in NumOfPredictDayList:
            for Epoch in EpochList:
                ModelInformation.iloc[count,0] = Filename
                ModelInformation.iloc[count,1] = ColumnList
                ModelInformation.iloc[count,2] = WindowSize
                ModelInformation.iloc[count,3] = NumOfPredictDay
                ModelInformation.iloc[count,4] = Layer
                ModelInformation.iloc[count,5] = Loss
                ModelInformation.iloc[count,6] = Optimizer
                ModelInformation.iloc[count,7] = BatchSize
                ModelInformation.iloc[count,8] = Epoch
                ModelInformation.iloc[count,9] = ValidationSplit
                ModelInformation.iloc[count,10] = str(count) + ".h5"
                #print(count,end=' ')
                count += 1

ModelInformation.to_csv('../model/ModelInformation.csv')
ModelInformation
# Out:
# 4
# 3
# 4
# 4
# 192
#      FileName                                    ColumnList WindowSize  \
# 0    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 1    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 2    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 3    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 4    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 5    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 6    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 7    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 8    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 9    2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 10   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 11   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 12   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 13   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 14   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 15   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]         50
# 16   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 17   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 18   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 19   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 20   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 21   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 22   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 23   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 24   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 25   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 26   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 27   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 28   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 29   2002.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# ..        ...                                           ...        ...
# 162  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 163  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 164  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 165  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 166  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 167  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 168  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 169  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 170  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 171  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 172  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 173  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 174  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 175  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        100
# 176  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 177  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 178  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 179  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 180  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 181  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 182  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 183  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 184  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 185  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 186  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 187  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 188  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 189  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 190  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
# 191  3008.csv  [成交股數, 成交金額, 成交筆數, 開盤價, 最後揭示買價, 最後揭示賣價, 收盤價]        150
#
#     NumOfPredictDay             Layer Loss Optimizer ValidationSplit  \
# 0                 3  [7, 50, 100, 30]  mse      adam             512
# 1                 3  [7, 50, 100, 30]  mse      adam             512
# 2                 3  [7, 50, 100, 30]  mse      adam             512
# 3                 3  [7, 50, 100, 30]  mse      adam             512
# 4                 7  [7, 50, 100, 30]  mse      adam             512
# 5                 7  [7, 50, 100, 30]  mse      adam             512
# 6                 7  [7, 50, 100, 30]  mse      adam             512
# 7                 7  [7, 50, 100, 30]  mse      adam             512
# 8                10  [7, 50, 100, 30]  mse      adam             512
# 9                10  [7, 50, 100, 30]  mse      adam             512
# 10               10  [7, 50, 100, 30]  mse      adam             512
# 11               10  [7, 50, 100, 30]  mse      adam             512
# 12               30  [7, 50, 100, 30]  mse      adam             512
# 13               30  [7, 50, 100, 30]  mse      adam             512
# 14               30  [7, 50, 100, 30]  mse      adam             512
# 15               30  [7, 50, 100, 30]  mse      adam             512
# 16                3  [7, 50, 100, 30]  mse      adam             512
# 17                3  [7, 50, 100, 30]  mse      adam             512
# 18                3  [7, 50, 100, 30]  mse      adam             512
# 19                3  [7, 50, 100, 30]  mse      adam             512
# 20                7  [7, 50, 100, 30]  mse      adam             512
# 21                7  [7, 50, 100, 30]  mse      adam             512
# 22                7  [7, 50, 100, 30]  mse      adam             512
# 23                7  [7, 50, 100, 30]  mse      adam             512
# 24               10  [7, 50, 100, 30]  mse      adam             512
# 25               10  [7, 50, 100, 30]  mse      adam             512
# 26               10  [7, 50, 100, 30]  mse      adam             512
# 27               10  [7, 50, 100, 30]  mse      adam             512
# 28               30  [7, 50, 100, 30]  mse      adam             512
# 29               30  [7, 50, 100, 30]  mse      adam             512
# ..              ...               ...  ...       ...             ...
# 162               3  [7, 50, 100, 30]  mse      adam             512
# 163               3  [7, 50, 100, 30]  mse      adam             512
# 164               7  [7, 50, 100, 30]  mse      adam             512
# 165               7  [7, 50, 100, 30]  mse      adam             512
# 166               7  [7, 50, 100, 30]  mse      adam             512
# 167               7  [7, 50, 100, 30]  mse      adam             512
# 168              10  [7, 50, 100, 30]  mse      adam             512
# 169              10  [7, 50, 100, 30]  mse      adam             512
# 170              10  [7, 50, 100, 30]  mse      adam             512
# 171              10  [7, 50, 100, 30]  mse      adam             512
# 172              30  [7, 50, 100, 30]  mse      adam             512
# 173              30  [7, 50, 100, 30]  mse      adam             512
# 174              30  [7, 50, 100, 30]  mse      adam             512
# 175              30  [7, 50, 100, 30]  mse      adam             512
# 176               3  [7, 50, 100, 30]  mse      adam             512
# 177               3  [7, 50, 100, 30]  mse      adam             512
# 178               3  [7, 50, 100, 30]  mse      adam             512
# 179               3  [7, 50, 100, 30]  mse      adam             512
# 180               7  [7, 50, 100, 30]  mse      adam             512
# 181               7  [7, 50, 100, 30]  mse      adam             512
# 182               7  [7, 50, 100, 30]  mse      adam             512
# 183               7  [7, 50, 100, 30]  mse      adam             512
# 184              10  [7, 50, 100, 30]  mse      adam             512
# 185              10  [7, 50, 100, 30]  mse      adam             512
# 186              10  [7, 50, 100, 30]  mse      adam             512
# 187              10  [7, 50, 100, 30]  mse      adam             512
# 188              30  [7, 50, 100, 30]  mse      adam             512
# 189              30  [7, 50, 100, 30]  mse      adam             512
# 190              30  [7, 50, 100, 30]  mse      adam             512
# 191              30  [7, 50, 100, 30]  mse      adam             512
#
#     BatchSize Epoch ModelName
# 0           1   0.1      0.h5
# 1           5   0.1      1.h5
# 2          10   0.1      2.h5
# 3          50   0.1      3.h5
# 4           1   0.1      4.h5
# 5           5   0.1      5.h5
# 6          10   0.1      6.h5
# 7          50   0.1      7.h5
# 8           1   0.1      8.h5
# 9           5   0.1      9.h5
# 10         10   0.1     10.h5
# 11         50   0.1     11.h5
# 12          1   0.1     12.h5
# 13          5   0.1     13.h5
# 14         10   0.1     14.h5
# 15         50   0.1     15.h5
# 16          1   0.1     16.h5
# 17          5   0.1     17.h5
# 18         10   0.1     18.h5
# 19         50   0.1     19.h5
# 20          1   0.1     20.h5
# 21          5   0.1     21.h5
# 22         10   0.1     22.h5
# 23         50   0.1     23.h5
# 24          1   0.1     24.h5
# 25          5   0.1     25.h5
# 26         10   0.1     26.h5
# 27         50   0.1     27.h5
# 28          1   0.1     28.h5
# 29          5   0.1     29.h5
# ..        ...   ...       ...
# 162        10   0.1    162.h5
# 163        50   0.1    163.h5
# 164         1   0.1    164.h5
# 165         5   0.1    165.h5
# 166        10   0.1    166.h5
# 167        50   0.1    167.h5
# 168         1   0.1    168.h5
# 169         5   0.1    169.h5
# 170        10   0.1    170.h5
# 171        50   0.1    171.h5
# 172         1   0.1    172.h5
# 173         5   0.1    173.h5
# 174        10   0.1    174.h5
# 175        50   0.1    175.h5
# 176         1   0.1    176.h5
# 177         5   0.1    177.h5
# 178        10   0.1    178.h5
# 179        50   0.1    179.h5
# 180         1   0.1    180.h5
# 181         5   0.1    181.h5
# 182        10   0.1    182.h5
# 183        50   0.1    183.h5
# 184         1   0.1    184.h5
# 185         5   0.1    185.h5
# 186        10   0.1    186.h5
# 187        50   0.1    187.h5
# 188         1   0.1    188.h5
# 189         5   0.1    189.h5
# 190        10   0.1    190.h5
# 191        50   0.1    191.h5
#
# [192 rows x 11 columns]
