# %%
import os
import pandas as pd
import numpy as np

#建立Model Information的Schema
if not os.path.isdir("../model"):
    os.makedirs("../model")
    
SchemaColumn = ['Name','Description','Sample']

SchemaName = ['FileName','ColumnList','WindowSize','NumOfPredictDay','Layer',
              'Loss','Optimizer','BatchSize','Epoch','ValidationSplit','ModelName']

SchemaDescription = ['檔案名稱','選擇的Column','以過去幾天的資料去做訓練、預測','要預測的天數','神經網路的層數',
                     'Loss Function的選擇','優化器的選擇','驗證集比例','訓練時Batch的大小',
                     '訓練幾次','儲存Model的名稱']

SchemaSample = ['2002.csv,3008.csv',"['成交股數','成交金額','開盤價','最高價','最低價','收盤價','漲跌價差','成交筆數']",
                '50','1,7,10,30','[len(ColumnList), 50, 100,NumOfPredictDay]','mse','adam','0.1','512',
                '10','0.h5,1.h5,2.h5']

ModelInformationSchema = pd.DataFrame(columns=SchemaColumn,index=range(len(SchemaName)))
for i in range(len(SchemaName)):
    ModelInformationSchema.iloc[i,0] = SchemaName[i]
    ModelInformationSchema.iloc[i,1] = SchemaDescription[i]
    ModelInformationSchema.iloc[i,2] = SchemaSample[i]
    #print(SchemaName[i],SchemaDescription[i],SchemaSample2[i])
    
ModelInformationSchema.to_csv('../model/ModelInformationSchema.csv')
#ModelInformationSchema
#len(SchemaName)

# %%
Filename = "2002.csv"
ColumnList = ['成交股數','成交金額','開盤價','最高價','最低價','收盤價','漲跌價差','成交筆數',]
WindowSize = 50
NumOfPredictDay = 30

Layer = [len(ColumnList), 50, 100,NumOfPredictDay]
Loss = "mse"
Optimizer = "adam"

BatchSize = 512
Epoch = 5
ValidationSplit = 0.1

import os
DirList = list(os.listdir("../data"))[0:-2]

FilenameList = DirList
#ColumnList = []
WindowSizeList = [30,60,90,180]
NumOfPredictDayList = [7,14,30]
#Layer = []
#Loss = []
#Optimizer = []
#BatchSize = []
EpochList = [5]
#ValidationSplit = []
                
#建立Model Information

ModelInformationColumn = SchemaName

NumofIndex = len(FilenameList)*len(WindowSizeList)*len(NumOfPredictDayList)*len(EpochList)
ModelInformation = pd.DataFrame(columns=ModelInformationColumn,index=range(NumofIndex)) 

count = 0
for Filename in FilenameList:
    for WindowSize in WindowSizeList:
        for NumOfPredictDay in NumOfPredictDayList:
            for Epoch in EpochList:
                Layer = [len(ColumnList), 50, 100,NumOfPredictDay]
                ModelInformation.iloc[count,0] = Filename
                ModelInformation.iloc[count,1] = ColumnList
                ModelInformation.iloc[count,2] = WindowSize
                ModelInformation.iloc[count,3] = NumOfPredictDay
                ModelInformation.iloc[count,4] = Layer
                ModelInformation.iloc[count,5] = Loss
                ModelInformation.iloc[count,6] = Optimizer
                ModelInformation.iloc[count,7] = BatchSize
                ModelInformation.iloc[count,8] = Epoch
                ModelInformation.iloc[count,9] = ValidationSplit
                ModelInformation.iloc[count,10] = str(count) + ".h5"
                #print(count,end=' ')
# 79  3008.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         90
# 80  3008.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         90
# 81  3008.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...        180
# 82  3008.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...        180
# 83  3008.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...        180
# 84  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         30
# 85  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         30
# 86  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         30
# 87  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         60
# 88  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         60
# 89  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         60
# 90  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         90
# 91  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         90
# 92  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...         90
# 93  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...        180
# 94  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...        180
# 95  3481.csv  [日期, 時間戳, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差...        180
#
#    NumOfPredictDay              Layer Loss Optimizer BatchSize Epoch  \
# 0                7   [10, 50, 100, 7]  mse      adam       512     5
# 1               14  [10, 50, 100, 14]  mse      adam       512     5
# 2               30  [10, 50, 100, 30]  mse      adam       512     5
# 3                7   [10, 50, 100, 7]  mse      adam       512     5
# 4               14  [10, 50, 100, 14]  mse      adam       512     5
# 5               30  [10, 50, 100, 30]  mse      adam       512     5
# 6                7   [10, 50, 100, 7]  mse      adam       512     5
# 7               14  [10, 50, 100, 14]  mse      adam       512     5
# 8               30  [10, 50, 100, 30]  mse      adam       512     5
# 9                7   [10, 50, 100, 7]  mse      adam       512     5
# 10              14  [10, 50, 100, 14]  mse      adam       512     5
# 11              30  [10, 50, 100, 30]  mse      adam       512     5
# 12               7   [10, 50, 100, 7]  mse      adam       512     5
# 13              14  [10, 50, 100, 14]  mse      adam       512     5
# 14              30  [10, 50, 100, 30]  mse      adam       512     5
# 15               7   [10, 50, 100, 7]  mse      adam       512     5
# 16              14  [10, 50, 100, 14]  mse      adam       512     5
# 17              30  [10, 50, 100, 30]  mse      adam       512     5
# 18               7   [10, 50, 100, 7]  mse      adam       512     5
# 19              14  [10, 50, 100, 14]  mse      adam       512     5
# 20              30  [10, 50, 100, 30]  mse      adam       512     5
# 21               7   [10, 50, 100, 7]  mse      adam       512     5
# 22              14  [10, 50, 100, 14]  mse      adam       512     5
# 23              30  [10, 50, 100, 30]  mse      adam       512     5
# 24               7   [10, 50, 100, 7]  mse      adam       512     5
# 25              14  [10, 50, 100, 14]  mse      adam       512     5
# 26              30  [10, 50, 100, 30]  mse      adam       512     5
# 27               7   [10, 50, 100, 7]  mse      adam       512     5
# 28              14  [10, 50, 100, 14]  mse      adam       512     5
# 29              30  [10, 50, 100, 30]  mse      adam       512     5
# ..             ...                ...  ...       ...       ...   ...
# 66               7   [10, 50, 100, 7]  mse      adam       512     5
# 67              14  [10, 50, 100, 14]  mse      adam       512     5
# 68              30  [10, 50, 100, 30]  mse      adam       512     5
# 69               7   [10, 50, 100, 7]  mse      adam       512     5
# 70              14  [10, 50, 100, 14]  mse      adam       512     5
# 71              30  [10, 50, 100, 30]  mse      adam       512     5
# 72               7   [10, 50, 100, 7]  mse      adam       512     5
# 73              14  [10, 50, 100, 14]  mse      adam       512     5
# 74              30  [10, 50, 100, 30]  mse      adam       512     5
# 75               7   [10, 50, 100, 7]  mse      adam       512     5
# 76              14  [10, 50, 100, 14]  mse      adam       512     5
# 77              30  [10, 50, 100, 30]  mse      adam       512     5
# 78               7   [10, 50, 100, 7]  mse      adam       512     5
# 79              14  [10, 50, 100, 14]  mse      adam       512     5
# 80              30  [10, 50, 100, 30]  mse      adam       512     5
# 81               7   [10, 50, 100, 7]  mse      adam       512     5
# 82              14  [10, 50, 100, 14]  mse      adam       512     5
# 83              30  [10, 50, 100, 30]  mse      adam       512     5
# 84               7   [10, 50, 100, 7]  mse      adam       512     5
# 85              14  [10, 50, 100, 14]  mse      adam       512     5
# 86              30  [10, 50, 100, 30]  mse      adam       512     5
# 87               7   [10, 50, 100, 7]  mse      adam       512     5
# 88              14  [10, 50, 100, 14]  mse      adam       512     5
# 89              30  [10, 50, 100, 30]  mse      adam       512     5
# 90               7   [10, 50, 100, 7]  mse      adam       512     5
# 91              14  [10, 50, 100, 14]  mse      adam       512     5
# 92              30  [10, 50, 100, 30]  mse      adam       512     5
# 93               7   [10, 50, 100, 7]  mse      adam       512     5
# 94              14  [10, 50, 100, 14]  mse      adam       512     5
# 95              30  [10, 50, 100, 30]  mse      adam       512     5
#
#    ValidationSplit ModelName
# 0              0.1      0.h5
# 1              0.1      1.h5
# 2              0.1      2.h5
# 3              0.1      3.h5
# 4              0.1      4.h5
# 5              0.1      5.h5
# 6              0.1      6.h5
# 7              0.1      7.h5
# 8              0.1      8.h5
# 9              0.1      9.h5
# 10             0.1     10.h5
# 11             0.1     11.h5
# 12             0.1     12.h5
# 13             0.1     13.h5
# 14             0.1     14.h5
# 15             0.1     15.h5
# 16             0.1     16.h5
# 17             0.1     17.h5
# 18             0.1     18.h5
# 19             0.1     19.h5
# 20             0.1     20.h5
# 21             0.1     21.h5
# 22             0.1     22.h5
# 23             0.1     23.h5
# 24             0.1     24.h5
# 25             0.1     25.h5
# 26             0.1     26.h5
# 27             0.1     27.h5
# 28             0.1     28.h5
# 29             0.1     29.h5
# ..             ...       ...
# 66             0.1     66.h5
# 67             0.1     67.h5
# 68             0.1     68.h5
# 69             0.1     69.h5
# 70             0.1     70.h5
# 71             0.1     71.h5
# 72             0.1     72.h5
# 73             0.1     73.h5
# 74             0.1     74.h5
# 75             0.1     75.h5
# 76             0.1     76.h5
# 77             0.1     77.h5
# 78             0.1     78.h5
# 79             0.1     79.h5
# 80             0.1     80.h5
# 81             0.1     81.h5
# 82             0.1     82.h5
# 83             0.1     83.h5
# 84             0.1     84.h5
# 85             0.1     85.h5
# 86             0.1     86.h5
# 87             0.1     87.h5
# 88             0.1     88.h5
# 89             0.1     89.h5
# 90             0.1     90.h5
# 91             0.1     91.h5
# 92             0.1     92.h5
# 93             0.1     93.h5
# 94             0.1     94.h5
# 95             0.1     95.h5
#
# [96 rows x 11 columns]

# %%
#建立Predict Information的Schema
if not os.path.isdir("../predict"):
    os.makedirs("../predict")
    
SchemaColumn = ['Name','Description','Sample']

SchemaName = ['FileName','WindowSize','NumOfPredictDay','PredictCSVName']

SchemaDescription = ['檔案名稱','以過去幾天的資料去做訓練','要預測的天數','儲存Predict結果的CSV名稱']

SchemaSample = ['2002.csv,3008.csv','50','1,7,10,30','0.csv,1.csv,2.csv']

PredictInformationSchema = pd.DataFrame(columns=SchemaColumn,index=range(len(SchemaName)))
for i in range(len(SchemaName)):
    PredictInformationSchema.iloc[i,0] = SchemaName[i]
    PredictInformationSchema.iloc[i,1] = SchemaDescription[i]
    PredictInformationSchema.iloc[i,2] = SchemaSample[i]
    #print(SchemaName[i],SchemaDescription[i],SchemaSample2[i])
    

PredictInformationSchema.to_csv('../predict/PredictInformationSchema.csv')
#PredictInformationSchema
#len(SchemaName)

# %%
ModelInformation = pd.read_pickle('../model/ModelInformation.pickle')
len(ModelInformation.columns)
len(ModelInformation)

#建立Model Information
PredictInformationColumn = SchemaName
NumofIndex = len(ModelInformation)
PredictInformation = pd.DataFrame(columns=PredictInformationColumn,index=range(NumofIndex))
#PredictInformation

count = 0
for i in range(len(ModelInformation)):
    PredictInformation['FileName'][i] = ModelInformation['FileName'][i]
    PredictInformation['WindowSize'][i] = ModelInformation['WindowSize'][i]
    PredictInformation['NumOfPredictDay'][i] = ModelInformation['NumOfPredictDay'][i]
    PredictInformation['PredictCSVName'][i] = str(count) + ".csv"
    count += 1

PredictInformation.to_csv('../predict/PredictInformation.csv')
PredictInformation.to_pickle('../predict/PredictInformation.pickle')
PredictInformation
# Out:
#     FileName WindowSize NumOfPredictDay PredictCSVName
# 0   1560.csv         30               7          0.csv
# 1   1560.csv         30              14          1.csv
# 2   1560.csv         30              30          2.csv
# 3   1560.csv         60               7          3.csv
# 4   1560.csv         60              14          4.csv
# 5   1560.csv         60              30          5.csv
# 6   1560.csv         90               7          6.csv
# 7   1560.csv         90              14          7.csv
# 8   1560.csv         90              30          8.csv
# 9   1560.csv        180               7          9.csv
# 10  1560.csv        180              14         10.csv
# 11  1560.csv        180              30         11.csv
# 12  2002.csv         30               7         12.csv
# 13  2002.csv         30              14         13.csv
# 14  2002.csv         30              30         14.csv
# 15  2002.csv         60               7         15.csv
# 16  2002.csv         60              14         16.csv
# 17  2002.csv         60              30         17.csv
# 18  2002.csv         90               7         18.csv
# 19  2002.csv         90              14         19.csv
# 20  2002.csv         90              30         20.csv
# 21  2002.csv        180               7         21.csv
# 22  2002.csv        180              14         22.csv
# 23  2002.csv        180              30         23.csv
# 24  2317.csv         30               7         24.csv
# 25  2317.csv         30              14         25.csv
# 26  2317.csv         30              30         26.csv
# 27  2317.csv         60               7         27.csv
# 28  2317.csv         60              14         28.csv
# 29  2317.csv         60              30         29.csv
# ..       ...        ...             ...            ...
# 66  2409.csv         90               7         66.csv
# 67  2409.csv         90              14         67.csv
# 68  2409.csv         90              30         68.csv
# 69  2409.csv        180               7         69.csv
# 70  2409.csv        180              14         70.csv
# 71  2409.csv        180              30         71.csv
# 72  3008.csv         30               7         72.csv
# 73  3008.csv         30              14         73.csv
# 74  3008.csv         30              30         74.csv
# 75  3008.csv         60               7         75.csv
# 76  3008.csv         60              14         76.csv
# 77  3008.csv         60              30         77.csv
# 78  3008.csv         90               7         78.csv
# 79  3008.csv         90              14         79.csv
# 80  3008.csv         90              30         80.csv
# 81  3008.csv        180               7         81.csv
# 82  3008.csv        180              14         82.csv
# 83  3008.csv        180              30         83.csv
# 84  3481.csv         30               7         84.csv
# 85  3481.csv         30              14         85.csv
# 86  3481.csv         30              30         86.csv
# 87  3481.csv         60               7         87.csv
# 88  3481.csv         60              14         88.csv
# 89  3481.csv         60              30         89.csv
# 90  3481.csv         90               7         90.csv
# 91  3481.csv         90              14         91.csv
# 92  3481.csv         90              30         92.csv
# 93  3481.csv        180               7         93.csv
# 94  3481.csv        180              14         94.csv
# 95  3481.csv        180              30         95.csv
#
# [96 rows x 4 columns]
